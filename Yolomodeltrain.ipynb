# %%
# !pip install ultralytics --upgrade
# !pip install opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
images_path = "/content/drive/MyDrive/boneimages"

# %%
import os
print(os.listdir(images_path))
# Out:
# ['data.yaml', 'train', 'valid', 'test']

# %%
# !pip install ultralytics --upgrade

# %%
Data_yaml = """
train: /content/drive/MyDrive/boneimages/train/images
val: /content/drive/MyDrive/boneimages/valid/images

nc: 7
names:
  - elbow positive
  - fingers positive
  - forearm fracture
  - humerus fracture
  - humerus
  - shoulder fracture
  - wrist positive
"""

with open("/content/drive/MyDrive/boneimages/data_fixed.yaml", "w") as f:
    f.write(Data_yaml)

# %%
# !yolo detect train \
    model=yolov8n.pt \
    data=/content/drive/MyDrive/boneimages/data_fixed.yaml \
    epochs=100 \
    imgsz=640 \
    batch=16 \
    device=0 \
    project=/content/drive/MyDrive/boneimages/yolo_runs \
    name=run1 \
    exist_ok=True
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/boneimages/yolo_runs/run1/weights/best.pt \
    source=/content/drive/MyDrive/boneimages/test/images \
    save=True
# Out:
# Ultralytics 8.3.246 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/169 /content/drive/MyDrive/boneimages/test/images/distal-humerus-fracture-1_jpg.rf.831cb137cfcbde1079f86abd5f5f2867.jpg: 640x256 (no detections), 47.7ms
# image 2/169 /content/drive/MyDrive/boneimages/test/images/image1_0_png.rf.99862308d714bff3f9c410adf5ca93ac.jpg: 480x640 1 fingers positive, 79.0ms
# image 3/169 /content/drive/MyDrive/boneimages/test/images/image1_1000_png.rf.a53c5e186c03961bf88075c6e3e94cf6.jpg: 544x640 (no detections), 54.4ms
# image 4/169 /content/drive/MyDrive/boneimages/test/images/image1_1015_png.rf.3b7320c3c40771fa5532bf713a728b83.jpg: 544x640 (no detections), 9.2ms
# image 5/169 /content/drive/MyDrive/boneimages/test/images/image1_1015_png.rf.9181f8eb07451331e22381bacb3a5bd2.jpg: 640x640 (no detections), 8.1ms
# ...
